# %%
import pickle

# %%
META_PATH = "index/meta.pkl"
with open(META_PATH, "rb") as f:
    meta = pickle.load(f)
meta
# Out:
# ['Apoorva S Shekhawat +91-9680249226 shekhawat.apoorva95@gmail.com linkedin.com/in/apoorva-shekhawat EXPERIENCE Data Scientist | INFOEDGE INDIA LIMITED Aug’ 22 – Present Data Science initiatives – Aisle Dating app \uf0b7 Leading a 2 member DS team; partnered with Product, Marketing and CBO to drive engagement and monetization. \uf0b7 Delivered tree-based paying propensity model reused across lookalike marketing for Meta and Google ad campaign, promotional pricing and plan recommendation driving +48% CVR and lowering CPA 42% & CPI 61%. \uf0b7 Spearheading development and deployment of ML-powered recommendation systems (item2vec, tree-based). Production-Ready Dynamic Pricing System using Paying propensity \uf0b7 Architected & deployed a full-funnel dynamic pricing engine using an ensemble (Random Forest, Logistic Regression, Sentence Transformers, Qwen) to perform lifecycle-based pay-propensity segmentation from profile, behavioral, and engagement signals. \uf0b7 Implemented a RL based
# ...
